# %%
import pandas as pd
import requests

url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'}

response = requests.get(url, headers=headers)
tables = pd.read_html(response.text)
symbols = tables[0]['Symbol'].tolist()

print(f"Total tickers: {len(symbols)}")
print(symbols[:10])
# Out:
# Total tickers: 503
# ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A']
# /var/folders/mb/tkf0q4qs2n1f24l8b53m7jyh0000gn/T/ipykernel_48384/3292382361.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(response.text)

# %%
import yfinance as yf
for symbol in symbols:
    if not os.path.exists(f"data/{symbol}.csv"):
        data = yf.download(symbol, start="2010-01-31", end="2018-12-31")
        if data.size > 0:
            data.to_csv(f"data/{symbol}.csv")
            print(f"Symbol {symbol} downloaded")
        else:
            print(f"Symbol {symbol} data not found!")

# %%
import pandas as pd
from glob import glob

files = glob('data/*.csv')
dfs = []

for f in files:
    df = pd.read_csv(f)
    symbol = f.split('/')[1].split('.')[0]
    print(f"Loading symbol {symbol}")
    df['name'] = symbol
    dfs.append(df)

dfs.to_csv('sp500full.csv', index = False)
